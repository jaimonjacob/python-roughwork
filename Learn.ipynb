# %% [markdown]
# Loading the dataset from google drive

# %%
# Importing google drive
from google.colab import drive
drive.mount('/content/drive')

# Assigning the file to be read to a variable
file_name = '/content/drive/MyDrive/Learn/lorem.txt'

# Opening the file
with open(file_name) as file_object:

  # reading each line
  lines = file_object.readlines()

new_string = ''

# Adding the content in the text file to the string variable
for line in lines:
  new_string += line.rstrip()

# Priting only the first few characters
print(new_string[:50])

# %% [markdown]
# 10.1_1

# %%
# Importing google drive
from google.colab import drive
drive.mount('/content/drive')

# Assigning the file to be read to a variable
file_name = '/content/drive/MyDrive/Learn/string.txt'

n = 3;
# Opening the file
with open(file_name) as file_object:
  content = file_object.read()
  for value in range(n):
    print(content)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Python is heavy
# Python is easy
# Python is lite
# Python is heavy
# Python is easy
# Python is lite
# Python is heavy
# Python is easy
# Python is lite

# %% [markdown]
# 10.1_2

# %%
lines = file_object.readlines()
